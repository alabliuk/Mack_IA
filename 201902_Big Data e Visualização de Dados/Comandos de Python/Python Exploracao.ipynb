# %%
#importar bibliotecas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
##importando a base de dados sobre qualidade do ar
dados = pd.read_csv('C:/Users/andrea.longarini/Documents/Cursos/python/AirQualityUCI.csv', sep=';')

# %%
# imprimindo os dez primeiros exemplos da base de dados
dados.head(10)
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6         1360       150     11,9           1046
# 1  10/03/2004  19.00.00      2         1292       112      9,4            955
# 2  10/03/2004  20.00.00    2,2         1402        88        9            939
# 3  10/03/2004  21.00.00    2,2         1376        80      9,2            948
# 4  10/03/2004  22.00.00    1,6         1272        51      6,5            836
# 5  10/03/2004  23.00.00    1,2         1197        38      4,7            750
# 6  11/03/2004  00.00.00    1,2         1185        31      3,6            690
# 7  11/03/2004  01.00.00      1         1136        31      3,3            672
# 8  11/03/2004  02.00.00    0,9         1094        24      2,3            609
# 9  11/03/2004  03.00.00    0,6         1010        19      1,7            561
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# ...

# %%
# calculando a media para todos os atributos
dados.describe()
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  9357.000000  9357.000000    9357.000000  9357.000000   9357.000000
# mean   1048.990061  -159.090093     894.595276   168.616971    794.990168
# std     329.832710   139.789093     342.333252   257.433866    321.993552
# min    -200.000000  -200.000000    -200.000000  -200.000000   -200.000000
# 25%     921.000000  -200.000000     711.000000    50.000000    637.000000
# 50%    1053.000000  -200.000000     895.000000   141.000000    794.000000
# 75%    1221.000000  -200.000000    1105.000000   284.000000    960.000000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)
# count  9357.000000   9357.000000  9357.000000
# mean     58.148873   1391.479641   975.072032
# std     126.940455    467.210125   456.938184
# min    -200.000000   -200.000000  -200.000000
# 25%      53.000000   1185.000000   700.000000
# ...

# %%
# calculando a mediana para todos os atributos
print(dados.median())
# Out:
# PT08.S1(CO)      1053.0
# NMHC(GT)         -200.0
# PT08.S2(NMHC)     895.0
# NOx(GT)           141.0
# PT08.S3(NOx)      794.0
# NO2(GT)            96.0
# PT08.S4(NO2)     1446.0
# PT08.S5(O3)       942.0
# dtype: float64

# %%
# calculando a mediana para todos os atributos
print(dados.mean())
# Out:
# PT08.S1(CO)      1048.990061
# NMHC(GT)         -159.090093
# PT08.S2(NMHC)     894.595276
# NOx(GT)           168.616971
# PT08.S3(NOx)      794.990168
# NO2(GT)            58.148873
# PT08.S4(NO2)     1391.479641
# PT08.S5(O3)       975.072032
# dtype: float64

# %%
# calculando percentil 15% para todos os atributos
print(dados.quantile(0.15))
# Out:
# PT08.S1(CO)       862.0
# NMHC(GT)         -200.0
# PT08.S2(NMHC)     631.0
# NOx(GT)          -200.0
# PT08.S3(NOx)      550.0
# NO2(GT)          -200.0
# PT08.S4(NO2)     1014.0
# PT08.S5(O3)       567.0
# Name: 0.15, dtype: float64

# %%
# calculando o intervalo para todos os atributos
print(dados.max(numeric_only=True) - dados.min(numeric_only=True))
# Out:
# PT08.S1(CO)      2240
# NMHC(GT)         1389
# PT08.S2(NMHC)    2414
# NOx(GT)          1679
# PT08.S3(NOx)     2883
# NO2(GT)           540
# PT08.S4(NO2)     2975
# PT08.S5(O3)      2723
# dtype: int64

# %%
# calculando a variancia para todos os atributos
print(dados.var())
# Out:
# PT08.S1(CO)      108789.616511
# NMHC(GT)          19540.990493
# PT08.S2(NMHC)    117192.055185
# NOx(GT)           66272.195514
# PT08.S3(NOx)     103679.847274
# NO2(GT)           16113.879181
# PT08.S4(NO2)     218285.300489
# PT08.S5(O3)      208792.504430
# dtype: float64

# %%
# calculando o desvio-padrao para todos os atributos
print(dados.std())
# Out:
# PT08.S1(CO)      329.832710
# NMHC(GT)         139.789093
# PT08.S2(NMHC)    342.333252
# NOx(GT)          257.433866
# PT08.S3(NOx)     321.993552
# NO2(GT)          126.940455
# PT08.S4(NO2)     467.210125
# PT08.S5(O3)      456.938184
# dtype: float64

# %%
#aumenta o tamanho da figura
plt.rcParams['figure.figsize'] = (11,7)

# %%
from pandas.plotting import scatter_matrix
cores = [classe_cor for nome in dados]
scatter_matrix(dados)
plt.show()

# %%
# gerando bloxplot para os atributos da Iris
dados.plot(kind='box')
plt.title('Quartis')
plt.show()

# %%
#tendência para correlação positiva
plt.plot([1, 2, 3, 4])
plt.title('Correlação')
plt.xlabel('freq')
plt.ylabel('numeros')
plt.show()

# %%
#tendência para correlação negativa
plt.plot([4, 3, 2, 1])
plt.ylabel('some numbers')
plt.show()

# %%
#gráfico de barras demonstrando distribuição de dados
names = ['A', 'B', 'C']
values = [5, 50, 100]

plt.figure(figsize=(9, 3))

plt.bar(names, values)
plt.show()

# %%
#histograma
df.price.hist(bins=100).plot()
# Out:
# []

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['A', 'B', 'C']
values = [5, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
df = pd.read_csv('C:/Users/andrea.longarini/Documents/Cursos/python/iris.csv', names=names)
df.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width    class
# 0  sepal_length  sepal_width  petal_length  petal_width  species
# 1           5.1          3.5           1.4          0.2   setosa
# 2           4.9          3.0           1.4          0.2   setosa
# 3           4.7          3.2           1.3          0.2   setosa
# 4           4.6          3.1           1.5          0.2   setosa

# %%
df['class'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# species        1
# Name: class, dtype: int64

# %%
df["class"].value_counts().plot.pie()

# %%
#!pip install seaborn

# %%
#!pip install ggplot

# %%
import seaborn as sns
sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
g = sns.pairplot(iris)

# %%
g = sns.pairplot(iris, hue="species")

# %%
 g = sns.pairplot(iris, hue="species", palette="husl")

# %%
g = sns.pairplot(iris, vars=["sepal_width", "sepal_length"])

# %%
g = sns.pairplot(iris, diag_kind="kde")

# %%
g = sns.pairplot(iris, kind="reg")

# %%
 g = sns.pairplot(iris, diag_kind="kde", markers="+",
                  plot_kws=dict(s=50, edgecolor="b", linewidth=1),
                  diag_kws=dict(shade=True))

# %%
df["class"].value_counts().plot.bar()

# %%
df["class"].value_counts().plot.barh()

# %%
df["class"].value_counts().plot.barh(title="Classes Iris")

# %%
#"sepal_width", "sepal_length"
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='sepal_width',y='sepal_length',data=iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %%
g = (sns.jointplot("sepal_width", "sepal_length",data=iris, color="k").plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %%
fig=sns.jointplot(x='sepal_width',y='sepal_length',kind='hex',data=iris)

# %%
sns.jointplot("sepal_width", "sepal_length", data=iris, kind="reg")

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='species',y='sepal_width',data=iris,order=['virginica','versicolor','setosa'],linewidth=2.5,orient='v',dodge=False)

# %%
#iris.drop("Id", axis=1).boxplot(by="Species", figsize=(12, 6))
iris.boxplot(by="species", figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022CD96AD408>,
# ...
#       dtype=object)

# %%
iris.describe().plot(kind = "area",fontsize=27, figsize = (20,8), table = True,colormap="rainbow")
plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics of Iris Dataset")
# Out:
# Text(0.5, 1.0, 'General Statistics of Iris Dataset')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='species',y='sepal_width',data=iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='species',y='sepal_width',data=iris)
fig=sns.stripplot(x='species',y='sepal_width',data=iris,jitter=True,edgecolor='gray')

# %%
   
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width',data=iris)

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="species", y="petal_length", data=iris, inner=None)
ax = sns.swarmplot(x="species", y="petal_length", data=iris,color="white", edgecolor="black")

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %%
iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %%
sns.set(style="darkgrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x="species", y="petal_length", data=iris)

# %%
sns.set(style="darkgrid")
sc=iris[iris.species=='setosa'].plot(kind='scatter',x='sepal_length',y='sepal_width',color='red',label='Setosa')
iris[iris.species=='versicolor'].plot(kind='scatter',x='sepal_length',y='sepal_width',color='green',label='Versicolor',ax=sc)
iris[iris.species=='virginica'].plot(kind='scatter',x='sepal_length',y='sepal_width',color='orange', label='virginica', ax=sc)
sc.set_xlabel('Sepal Length in cm')
sc.set_ylabel('Sepal Width in cm')
sc.set_title('Sepal Length Vs Sepal Width')
sc=plt.gcf()
sc.set_size_inches(10,6)

# %%
fig=sns.lmplot(x="petal_length", y="petal_width",data=iris)

# %%
sns.FacetGrid(iris, hue="species", size=6) \
   .map(sns.kdeplot, "petal_length") \
   .add_legend()
plt.ioff()

# %%
#f,ax=plt.subplots(1,2,figsize=(18,8))
sns.factorplot('species','sepal_length',data=iris)
plt.ioff()
plt.show()
#sns.factorplot('Species','SepalLengthCm',data=iris,ax=ax[0][0])
#sns.factorplot('Species','SepalWidthCm',data=iris,ax=ax[0][1])
#sns.factorplot('Species','PetalLengthCm',data=iris,ax=ax[1][0])
#sns.factorplot('Species','PetalWidthCm',data=iris,ax=ax[1][1])

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(x='species',y='sepal_length',data=iris)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.residplot('sepal_length', 'sepal_width',data=iris,lowess=True)

# %%
from math import pi
categories = list(iris)[:4]
N = len(categories)
angles = [ n / float(N)*2*pi for n in range(N)]
angles = angles + angles[:1]
plt.figure(figsize = (10,10))
ax = plt.subplot(111,polar = True)
ax.set_theta_offset(pi/2)
ax.set_theta_direction(-1)
plt.xticks(angles[:-1],categories)
ax.set_rlabel_position(0)
plt.yticks([0,2,4,6],["0","2","4","6"],color= "red", size = 7)
plt.ylim(0,6)

values = iris.loc[0].drop("species").values.flatten().tolist()
values = values + values[:1]
ax.plot(angles,values,linewidth = 1,linestyle="solid",label ="setosa" )
ax.fill(angles,values,"b",alpha=0.1)

values = iris.loc[1].drop("species").values.flatten().tolist()
values = values + values[:1]
ax.plot(angles,values,linewidth = 1,linestyle="solid",label ="versicolor" )
ax.fill(angles,values,"orange",alpha=0.1)
plt.legend(loc = "upper left",bbox_to_anchor = (0.1,0.1))
plt.show()

# %%
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.
sub=iris[iris['species']=='setosa']
sns.kdeplot(data=sub[['sepal_length','sepal_width']],cmap="plasma", shade=True, shade_lowest=False)
plt.title('setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# ...
# Text(0, 0.5, 'Sepal Width Cm')
